# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunJadhav-data/Airline-performance-revenue-analysis/blob/main/Airline_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/PIA_2026_Advanced_Kaggle_Dataset.csv')

# %%
data[['Revenue_USD', 'Passengers', 'Ticket_Price_USD', 'Load_Factor_%']].corr()
# Out:
#                   Revenue_USD  Passengers  Ticket_Price_USD  Load_Factor_%
# Revenue_USD          1.000000    0.727460          0.604237       0.249715
# Passengers           0.727460    1.000000          0.022294       0.329220
# Ticket_Price_USD     0.604237    0.022294          1.000000      -0.001940
# Load_Factor_%        0.249715    0.329220         -0.001940       1.000000

# %%
data[['Passengers','Revenue_USD']].mean()
# Out:
# Passengers        143.27750
# Revenue_USD    115149.45875
# dtype: float64

# %% [markdown]
# Which flights are generating highest and lowest revenue?

# %%
data[['Flight_ID','Revenue_USD']].max()
# Out:
# Flight_ID      PK2026_0800
# Revenue_USD         494654
# dtype: object

# %%
data[['Flight_ID','Revenue_USD']].min()
# Out:
# Flight_ID      PK2026_0001
# Revenue_USD           4712
# dtype: object

# %% [markdown]
# 4 . Is there any relationship between ticket price and revenue?

# %%
data[['Ticket_Price_USD','Revenue_USD']].corr()
# Out:
#                   Ticket_Price_USD  Revenue_USD
# Ticket_Price_USD          1.000000     0.604237
# Revenue_USD               0.604237     1.000000

# %% [markdown]
# 5 .
# Which range of ticket prices gives maximum profit?

# %%
data.info()

# %%
data = data.drop('Unnamed: 15', axis=1)

# %% [markdown]
# remove umwanted data from your table

# %%
data.info()

# %%
data.groupby('Customer_Rating')['Customer_Rating']

# %%
data.gropuby('Customer_Rating')['Revenue_USD']

# %%
data

# %%
s=data.groupby('Customer_Rating')

# %%
s

# %%
data.groupby('Aircraft_Type')['Customer_Rating'].mean()

# %%
data.info()

# %%
data[['Aircraft_Type','Customer_Rating']].groupby('Aircraft_Type')

# %%
data.groupby('Aircraft_Type')['Customer_Rating'].mean()

# %%
data[['Aircraft_Type','Customer_Rating']].groupby('Customer_Rating')

# %%
data[['Aircraft_Type','Customer_Rating']].groupby('Aircraft_Type')

# %%
data[['Customer_Rating','Aircraft_Type']].groupby('Customer_Rating')

# %%
data.groupby('Customer_Rating')['Aircraft_Type'].sum()

# %% [markdown]
# #Average rating by Aircrate wise

# %%
data.groupby('Aircraft_Type')['Customer_Rating'].mean().sort_values(ascending=False)

# %%
data.groupby('Customer_Rating')[['Flight_Duration_Minutes','Delay_Minutes','Customer_Rating','Customer_Feedback']].count()

# %% [markdown]
# # COUNTING MOST COMMAN FEEDBACK BY GIVEN CUSOMER BASED ON RATING

# %%
data.groupby('Customer_Feedback').mean('Customer_Rating')[['Customer_Rating','Customer_Rating']].count()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# This creates a visual map of your table
sns.heatmap(data[['Ticket_Price_USD', 'Revenue_USD']].corr(), annot=True, cmap='coolwarm')
plt.show()
