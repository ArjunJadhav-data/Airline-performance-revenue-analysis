# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunJadhav-data/Airline-performance-revenue-analysis/blob/main/Order%20vs%20sale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import AST
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pf=pd.read_excel('/content/data.xlsx',header=2)

# %%
pf
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
pf
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
pf['SNO.'].isna()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 106     True
# 107    False
# 108    False
# 109     True
# 110     True
# Name: SNO., Length: 111, dtype: bool

# %%
pf['SNO.'].dropna(how='all')
# Out:
# 0       1.0
# 2       2.0
# 3       3.0
# 5       4.0
# 6       5.0
#        ...
# 102    66.0
# 104    67.0
# 105    68.0
# 107    69.0
# 108    70.0
# Name: SNO., Length: 70, dtype: float64

# %%
pf
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
pf['SNO.'].isna().sum()
# Out:
# np.int64(41)

# %%
pf['SNO.'].dropna()
# Out:
# 0       1.0
# 2       2.0
# 3       3.0
# 5       4.0
# 6       5.0
#        ...
# 102    66.0
# 104    67.0
# 105    68.0
# 107    69.0
# 108    70.0
# Name: SNO., Length: 70, dtype: float64

# %%
pf
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
pf.to_csv('cleaned_data.csv', index=False)

# %%
from google.colab import files
files.download('cleaned_data.csv')

# %%
pf
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
pfata=pf.dropna(subset=['SNO.'])

# %%
pfata
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026       OOSPI0113  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026       OOSPI0164  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...

# %%
pfata.to_csv('cleaned_data1.csv', index=False)

# %%
from google.colab import files
files.download('cleaned_data1.csv')

# %%
pfata
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026       OOSPI0113  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026       OOSPI0164  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...

# %%
p=pfata

# %%
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026       OOSPI0113  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026       OOSPI0164  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...

# %%
p['PARTY ORDER NO.']
# Out:
# 0
# 2          PI012
# 3      OOSPI0112
# 5         PI0113
# 6      OOSPI0113
#          ...
# 102    oosPI0163
# 104       PI0164
# 105    OOSPI0164
# 107       PI0163
# 108    oosPI0163
# Name: PARTY ORDER NO., Length: 70, dtype: object

# %%
p['PARTY ORDER NO.']=p['PARTY ORDER NO.'].str.replace(r'oos\d+','oos',regex=True)
# Out:
# /tmp/ipykernel_802/1992474282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p['PARTY ORDER NO.']=p['PARTY ORDER NO.'].str.replace(r'oos\d+','oos',regex=True)

# %%
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026       OOSPI0113  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026       OOSPI0164  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...
