# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunJadhav-data/Airline-performance-revenue-analysis/blob/main/dataCleanigAndReplaceValues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from google.colab import files

# %%
p=pd.read_excel('/content/data.xlsx',header=2)
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
p.dropna(subset=['SNO.'])
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026       OOSPI0113  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026       OOSPI0164  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...

# %%
p['PARTY ORDER NO.']=p['PARTY ORDER NO.'].str.replace(r'oos\d+','oos',regex=True)
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 1     NaN                 NaN              NaN             NaN         NaN
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 4     NaN                 NaN              NaN             NaN         NaN
# ..    ...                 ...              ...             ...         ...
# 106   NaN                 NaN              NaN             NaN         NaN
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 109   NaN                 NaN              NaN             NaN         NaN
# 110   NaN                 NaN              NaN             NaN         NaN
#
# ...

# %%
p=p.dropna(subset=['SNO.'])
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026       OOSPI0113  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026       OOSPI0164  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...

# %%
p.loc[:,'PARTY ORDER NO.']=p['PARTY ORDER NO.'].str.replace(r'oos\d+','oos',regex=True)

# %%
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026       OOSPI0112  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026       OOSPI0113  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026       OOSPI0164  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026       oosPI0163  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...

# %%
p.loc[:,'PARTY ORDER NO.']=p['PARTY ORDER NO.'].str.replace(r'(?i)oos.*','oos',regex=True)
p
# Out:
#      SNO.         BRANCH NAME PARTY ORDER DATE PARTY ORDER NO.  ORDER DATE  \
# 0     1.0  1. PP/HO/MOTHER WH       02/04/2026                  02/04/2026
# 2     2.0  1. PP/HO/MOTHER WH       02/04/2026           PI012  02/04/2026
# 3     3.0  1. PP/HO/MOTHER WH       02/04/2026             oos  02/04/2026
# 5     4.0  1. PP/HO/MOTHER WH       03/04/2026          PI0113  03/04/2026
# 6     5.0  1. PP/HO/MOTHER WH       03/04/2026             oos  03/04/2026
# ..    ...                 ...              ...             ...         ...
# 102  66.0  1. PP/HO/MOTHER WH       17/04/2026             oos  17/04/2026
# 104  67.0  1. PP/HO/MOTHER WH       17/04/2026          PI0164  17/04/2026
# 105  68.0  1. PP/HO/MOTHER WH       17/04/2026             oos  17/04/2026
# 107  69.0  1. PP/HO/MOTHER WH       17/04/2026          PI0163  17/04/2026
# 108  70.0  1. PP/HO/MOTHER WH       17/04/2026             oos  17/04/2026
#
#      ORDER NO.                                     PARTY NAME  \
# ...

# %%
p.to_excel('file.xlsx', index=False)

# %%
files.download('file.xlsx')
